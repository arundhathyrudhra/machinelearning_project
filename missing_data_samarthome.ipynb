# %%
import pandas as pd
from google.colab import files
files.upload()
smarthome_data=pd.read_csv('smart_home_device_usage_data.csv')
smarthome_data
# Out:
#      <input type="file" id="files-78f30d19-8274-4aa2-9e73-72ee3d24fb7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78f30d19-8274-4aa2-9e73-72ee3d24fb7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
smarthome_data.shape
# Out:
# (5403, 8)

# %%
smarthome_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5403 entries, 0 to 5402
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserID                5403 non-null   int64
#  1   DeviceType            4936 non-null   object
#  2   UsageHoursPerDay      5017 non-null   float64
#  3   EnergyConsumption     5303 non-null   float64
#  4   UserPreferences       5403 non-null   int64
#  5   MalfunctionIncidents  5234 non-null   float64
#  6   DeviceAgeMonths       1040 non-null   float64
#  7   SmartHomeEfficiency   5403 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 337.8+ KB

# %%
smarthome_data.isnull().sum()
# Out:
# UserID                     0
# DeviceType               467
# UsageHoursPerDay         386
# EnergyConsumption        100
# UserPreferences            0
# MalfunctionIncidents     169
# DeviceAgeMonths         4363
# SmartHomeEfficiency        0
# dtype: int64

# %%
smarthome_data['DeviceType'].fillna(smarthome_data['DeviceType'].mode()[0],inplace=True)
smarthome_data['UsageHoursPerDay'].fillna(smarthome_data['UsageHoursPerDay'].mean(),inplace=True)
smarthome_data['EnergyConsumption'].fillna(smarthome_data['EnergyConsumption'].mean(),inplace=True)
smarthome_data['MalfunctionIncidents'].fillna(smarthome_data['MalfunctionIncidents'].mean(),inplace=True)
smarthome_data=smarthome_data.drop('DeviceAgeMonths',axis=1)
smarthome_data.isnull().sum()
# Out:
# UserID                  0
# DeviceType              0
# UsageHoursPerDay        0
# EnergyConsumption       0
# UserPreferences         0
# MalfunctionIncidents    0
# SmartHomeEfficiency     0
# dtype: int64
