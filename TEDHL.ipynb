# %%
# !pip install lightkurve
import lightkurve as lk
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.8/910.8 kB 47.4 MB/s eta 0:00:00
# ...
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=d8b2bdd891e4a0dc8e45d7066f5039ec577e799f8e1afe2ef241606905bc3f9e
#   Stored in directory: /root/.cache/pip/wheels/3c/ea/60/8d1c9fbbc99492a1775b36a5e29c8c1ef309cc5821bd5a219d
# ...
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50453 sha256=a88002a8d6a45df45171ac61da0c0e99ef7e9a6d741593b69e18a2d3fe088ea8
# ...

# %%
search_result=lk.search_targetpixelfile('Kepler-10')
search_result
# Out:
# SearchResult containing 70 data products.
#
#  #       mission      year   author  exptime  target_name  distance
#                                         s                   arcsec
# --- ----------------- ---- --------- ------- ------------- --------
#   0 Kepler Quarter 02 2009    Kepler      60 kplr011904151      0.0
#   1 Kepler Quarter 03 2009    Kepler      60 kplr011904151      0.0
#   2 Kepler Quarter 03 2009    Kepler      60 kplr011904151      0.0
#   3 Kepler Quarter 03 2009    Kepler      60 kplr011904151      0.0
#   4 Kepler Quarter 03 2009    Kepler    1800 kplr011904151      0.0
#   5 Kepler Quarter 00 2009    Kepler    1800 kplr011904151      0.0
#   6 Kepler Quarter 01 2009    Kepler    1800 kplr011904151      0.0
#   7 Kepler Quarter 02 2009    Kepler    1800 kplr011904151      0.0
#   8 Kepler Quarter 07 2010    Kepler      60 kplr011904151      0.0
#   9 Kepler Quarter 06 2010    Kepler      60 kplr011904151      0.0
# ...

# %%
tpf=search_result[45].download()
tpf.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/astropy/io/fits/fitsrec.py:700: UserWarning: Field 12 has a repeat count of 0 in its format code, indicating an empty field.
#   warnings.warn(
# <Axes: title={'center': 'Target ID: 11904151, Cadence: 2117740'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
search_result=lk.search_targetpixelfile('Kepler-10',radius=180.,exptime=1800)
search_result
# Out:
# SearchResult containing 136 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 00 2009 Kepler    1800 kplr011904151      0.0
#   1 Kepler Quarter 01 2009 Kepler    1800 kplr011904151      0.0
#   2 Kepler Quarter 02 2009 Kepler    1800 kplr011904151      0.0
#   3 Kepler Quarter 03 2009 Kepler    1800 kplr011904151      0.0
#   4 Kepler Quarter 04 2010 Kepler    1800 kplr011904151      0.0
#   5 Kepler Quarter 05 2010 Kepler    1800 kplr011904151      0.0
#   6 Kepler Quarter 06 2010 Kepler    1800 kplr011904151      0.0
#   7 Kepler Quarter 07 2010 Kepler    1800 kplr011904151      0.0
#   8 Kepler Quarter 09 2011 Kepler    1800 kplr011904151      0.0
#   9 Kepler Quarter 10 2011 Kepler    1800 kplr011904151      0.0
# ...               ...  ...    ...     ...           ...      ...
# ...

# %%
tpf.get_header(ext=0)
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# NEXTEND =                    2 / number of standard extensions
# EXTNAME = 'PRIMARY '           / name of extension
# EXTVER  =                    1 / extension version number (not format version)
# ORIGIN  = 'NASA/Ames'          / institution responsible for creating this file
# DATE    = '2016-06-03'         / file creation date.
# CREATOR = '1218742 TargetPixelExporterPipelineModule' / pipeline job and program
# PROCVER = 'svn+ssh://murzim/repo/soc/tags/release/9.3.48 r61429' / SW version
# FILEVER = '6.1     '           / file format version
# TIMVERSN= 'OGIP/93-003'        / OGIP memo number for file format
# TELESCOP= 'Kepler  '           / telescope
# INSTRUME= 'Kepler Photometer'  / detector type
# OBJECT  = 'KIC 11904151'       / string version of target id
# ...

# %%
tpf.wcs.pixel_to_world(0,0)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (285.68057738, 50.24656494)>

# %%
tpf.time
# Out:
# <Time object: scale='tdb' format='bkjd' value=[1559.21667079 1559.21735201 1559.21803313 ... 1581.59002839 1581.59070951
#  1581.59139063]>

# %%
tpf.time.iso
# Out:
# array(['2013-04-09 17:12:00.357', '2013-04-09 17:12:59.214',
#        '2013-04-09 17:13:58.062', ..., '2013-05-02 02:09:38.453',
#        '2013-05-02 02:10:37.301', '2013-05-02 02:11:36.150'], dtype='<U23')

# %%
tpf.time.utc.iso
# Out:
# array(['2013-04-09 17:10:53.171', '2013-04-09 17:11:52.028',
#        '2013-04-09 17:12:50.877', ..., '2013-05-02 02:08:31.267',
#        '2013-05-02 02:09:30.116', '2013-05-02 02:10:28.965'], dtype='<U23')

# %%
tpf.flux
# Out:
# <Quantity [[[1.36534454e+02, 2.11425995e+02, 6.08212402e+02, ...,
#              1.21100037e+03, 4.54650330e+02,            nan],
#             [2.06368530e+02, 5.16557983e+02, 4.28593408e+03, ...,
#              7.71657471e+03, 1.71609790e+03, 1.62621887e+02],
#             [1.43057373e+02, 3.19006897e+02, 1.02925586e+04, ...,
#              2.49380000e+04, 1.72870837e+03, 1.33746811e+02],
#             ...,
#             [6.09492760e+01, 1.71180222e+02, 1.24380615e+03, ...,
#              1.46666260e+04, 1.19721704e+03, 1.62097046e+02],
#             [6.62628937e+01, 6.08431358e+01, 6.19191223e+02, ...,
#              5.51159863e+03, 8.48032043e+02, 1.00736664e+02],
#             [1.49962454e+01, 3.75964966e+01, 2.76418732e+02, ...,
#              1.58793127e+03, 5.20776978e+02,            nan]],
#
#            [[1.29397064e+02, 2.19246140e+02, 5.97451904e+02, ...,
#              1.23013916e+03, 4.75095093e+02,            nan],
# ...

# %%
tpf.flux.shape
# Out:
# (32602, 8, 7)

# %%
fig,axes=plt.subplot(1,1,figsize=(16,16))
tpf.plot(ax=axes[0,0],column='FLUX')
tpf.plot(ax=axes[0,1],column='FLUX_BKG')
tpf.plot(ax=axes[1,0],column='FLUX_ERR')
tpf.plot(ax=axes[1,1],column='FLUX_BKG_ERR')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5f34d29a6448> in <cell line: 1>()
# ----> 1 fig,axes=plt.subplot(1,1,figsize=(16,16))
#       2 tpf.plot(ax=axes[0,0],column='FLUX')
#       3 tpf.plot(ax=axes[0,1],column='FLUX_BKG')
#       4 tpf.plot(ax=axes[1,0],column='FLUX_ERR')
#       5 tpf.plot(ax=axes[1,1],column='FLUX_BKG_ERR')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1321
#    1322     # First, search for an existing subplot with a matching spec.
# -> 1323     key = SubplotSpec._from_subplot_args(fig, args)
#    1324
#    1325     for ax in fig.axes:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     583             rows, cols, num = args
#     584         else:
# ...
